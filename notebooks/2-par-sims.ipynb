# %%
import os, sys
import numpy as np
import healpy as hp
import pickle
from matplotlib import pyplot as plt

# %%
data_dir = "/global/cfs/cdirs/des/mgatti/darkgrid_SC_nosyst/"
os.listdir(data_dir)[:5]
# Out:
# ['214_noiserel_0.pkl',
#  '253_noiserel_0.pkl',
#  '92_noiserel_0.pkl',
#  '191_noiserel_0.pkl',
#  '58_noiserel_0.pkl']

# %%
with open(data_dir + os.listdir(data_dir)[1], "rb") as f:
    cosmo = pickle.load(f)

# %%
key1, key2 = cosmo[0][1]["g1"], cosmo[1][1]["g1"]

# %%
hp.mollview(np.log10(np.abs(key1)), title="g1")

# %%
hp.mollview(np.log10(np.abs(key2)), title="g1")

# %%
hp.mollview(np.abs(key2 - key1), title="g1")

# %%
np.sum(cosmo[2][1]["g2"] - cosmo[1][1]["g2"])
# Out:
# 0.0

# %%
cosmo[0]["config"]
# Out:
# {'Om': 0.1789,
#  'sigma8': 1.1729,
#  'ns': 0.9649,
#  'Ob': 0.0493,
#  'h100': 67.36,
#  'nside_out': 512,
#  'nside2': 512,
#  'nside_intermediate': 1024,
#  'nside': 512,
#  'sources_bins': [1, 2, 3, 4],
#  'dz_sources': [0.0, 0.0, 0.0, 0.0],
#  'm_sources': [-0.002, -0.017, -0.029, -0.038],
#  'ms_sources': [0.0091, 0.0078, 0.0076, 0.0076],
#  'A_IA': 0.0,
#  'eta_IA': 0.0,
#  'f': 253,
#  'z0_IA': 0.67,
#  '2PT_FILE': '/global/cfs/cdirs//des/www/y3_chains/data_vectors/2pt_NG_final_2ptunblind_02_26_21_wnz_maglim_covupdate_6000HR.fits'}

# %%
cosmo[0].keys()
# Out:
# dict_keys([1, 2, 3, 4, 'nuisance_params', 'config'])

# %%
a = np.load("/pscratch/sd/s/shubh/20231010_224x224_patches/214_noiserel_0.npy")

# %%
plt.figure()
plt.imshow(a[1, :, :, 0], origin="lower")
plt.colorbar()
plt.show()
plt.close()

# %%
a = np.load("/pscratch/sd/s/shubh/20231010_224x224_kappa/214_noiserel_0.npz")["kappa"]

# %%
hp.mollview(a[1], title="kappa")
